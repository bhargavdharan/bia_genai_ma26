# %%
# %pip install llama-index-vector-stores-lancedb==0.4.1
# %pip install llama-index-multi-modal-llms-openai
# %pip install llama-index-embeddings-clip
# %pip install git+https://github.com/openai/CLIP.git
# !pip install llama-index-readers-file
# Out:
# ...
#   Cloning https://github.com/openai/CLIP.git to /tmp/pip-req-build-iqezteiw
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/CLIP.git /tmp/pip-req-build-iqezteiw
#   Resolved https://github.com/openai/CLIP.git to commit d05afc436d78f1c48dc0dbf8e5980a9d471f35f6
#   Preparing metadata (setup.py) ... done
# ...

# %%
# %pip install llama_index
# %pip install -U openai-whisper
# Out:
# ...
#   Attempting uninstall: llama-index-llms-openai
#     Found existing installation: llama-index-llms-openai 0.6.26
#     Uninstalling llama-index-llms-openai-0.6.26:
#       Successfully uninstalled llama-index-llms-openai-0.6.26
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llama-index-multi-modal-llms-openai 0.6.2 requires llama-index-llms-openai<0.7,>=0.6.0, but you have llama-index-llms-openai 0.7.9 which is incompatible.
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 803.2/803.2 kB 32.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 197.7/197.7 MB 6.6 MB/s eta 0:00:00
# ...

# %%
# %pip install lancedb
# %pip install moviepy
# %pip install yt_dlp
# %pip uninstall pytube -y
# %pip install git+https://github.com/pytube/pytube
# %pip install pytube
# %pip install pydub
# %pip install SpeechRecognition
# %pip install ffmpeg-python
# %pip install soundfile
# %pip install torch torchvision
# %pip install matplotlib scikit-image
# %pip install ftfy regex tqdm
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.8/183.8 kB 11.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 82.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.9/32.9 MB 44.7 MB/s eta 0:00:00
# ...

# %%
from moviepy.editor import VideoFileClip
from pathlib import Path
import speech_recognition as sr
from pprint import pprint
from PIL import Image
import matplotlib.pyplot as plt
# Out:
# /usr/local/lib/python3.12/dist-packages/moviepy/config_defaults.py:47: SyntaxWarning: invalid escape sequence '\P'
#   IMAGEMAGICK_BINARY = r"C:\Program Files\ImageMagick-6.8.8-Q16\magick.exe"
# /usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:294: SyntaxWarning: invalid escape sequence '\d'
#   lines_video = [l for l in lines if ' Video: ' in l and re.search('\d+x\d+', l)]
# /usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:367: SyntaxWarning: invalid escape sequence '\d'
#   rotation_lines = [l for l in lines if 'rotate          :' in l and re.search('\d+$', l)]
# /usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:370: SyntaxWarning: invalid escape sequence '\d'
#   match = re.search('\d+$', rotation_line)
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/sliders.py:61: SyntaxWarning: "is" with 'str' literal. Did you mean "=="?
#   if event.key is 'enter':
#
# ...

# %%
import os
# from dotenv import load_dotenv
# load_dotenv(override = True)


from google.colab import userdata
os.environ["OPENAI_API_KEY"] = userdata.get('OPENAI_API_KEY')

# %%
os.getcwd()
# Out:
# '/content'

# %%
video_url = "https://www.youtube.com/watch?v=tKPSmn-urB4"

# %%
output_video_path = "/content/video_data/"

# %%
output_folder = "/content/mixed_data/"
output_audio_path = "/content/mixed_data/output_audio.wav"

# %%
# !mkdir mixed_data # In VS Code, this might not work, manually create a folder with mixed_data name
# Out:
# mkdir: cannot create directory ‘mixed_data’: File exists

# %%
file_path = output_video_path + "input_vid.mp4"

# %%
file_path
# Out:
# '/content/video_data/input_vid.mp4'

# %%
import yt_dlp

# %%
def download_video(url, output_path):
  ydl_opts = {
      "outtmpl" : f'{output_path}/input_vid.%(ext)s',
      "format" : 'bestvideo[ext=mp4]+bestaudio[ext=m4a]/best[ext=mp4]/best',
      "merge_output_format" : "mp4"
  }

  with yt_dlp.YoutubeDL(ydl_opts) as ydl:
    info = ydl.extract_info(url, download = True)
    return {
        "Title" : info.get("title"),
        "Author" : info.get("uploader"),
        "Views" : info.get("view_count")
    }

# %%
video_url
# Out:
# 'https://www.youtube.com/watch?v=tKPSmn-urB4'

# %%
output_video_path
# Out:
# '/content/video_data/'

# %%
metadata_vid = download_video(video_url, output_video_path)
# Out:
# [youtube] Extracting URL: https://www.youtube.com/watch?v=tKPSmn-urB4
# [youtube] tKPSmn-urB4: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] tKPSmn-urB4: Downloading android vr player API JSON
# [info] tKPSmn-urB4: Downloading 1 format(s): 399+140
# [download] Destination: /content/video_data//input_vid.f399.mp4
# [download] 100% of   20.19MiB in 00:00:01 at 16.80MiB/s
# [download] Destination: /content/video_data//input_vid.f140.m4a
# [download] 100% of    2.72MiB in 00:00:00 at 47.18MiB/s
# [Merger] Merging formats into "/content/video_data//input_vid.mp4"
# Deleting original file /content/video_data//input_vid.f140.m4a (pass -k to keep)
# ...

# %%
# import yt_dlp
# import subprocess
# import os

# def download_and_clip_video(url, output_path, start_time=None, end_time=None, start_frame=None, end_frame=None):
#     """
#     Downloads a YouTube video and extracts a specific clip.

#     Args:
#         url (str): YouTube video URL
#         output_path (str): Directory to save the video
#         start_time (str): Start time in format 'HH:MM:SS' (optional)
#         end_time (str): End time in format 'HH:MM:SS' (optional)
#         start_frame (int): Start frame number (optional)
#         end_frame (int): End frame number (optional)
#     """
#     os.makedirs(output_path, exist_ok=True)
#     input_file = os.path.join(output_path, "input_vid.%(ext)s")
#     final_file = os.path.join(output_path, "clip.mp4")

#     # Step 1: Download video
#     ydl_opts = {
#         'outtmpl': input_file,
#         'format': 'bestvideo[ext=mp4]+bestaudio[ext=m4a]/best[ext=mp4]/best',
#         'merge_output_format': 'mp4'
#     }

#     with yt_dlp.YoutubeDL(ydl_opts) as ydl:
#         info = ydl.extract_info(url, download=True)
#         downloaded_file = ydl.prepare_filename(info).replace("%(ext)s", "mp4")

#     # Step 2: Build FFmpeg command
#     ffmpeg_cmd = ["ffmpeg", "-y", "-i", downloaded_file]

#     # Use timestamps
#     if start_time and end_time:
#         ffmpeg_cmd += ["-ss", start_time, "-to", end_time]
#     # Or use frame numbers
#     elif start_frame is not None and end_frame is not None:
#         ffmpeg_cmd += ["-vf", f"select='between(n\\,{start_frame}\\,{end_frame})',setpts=N/FRAME_RATE/TB"]

#     ffmpeg_cmd += ["-c", "copy", final_file]

#     # Step 3: Run FFmpeg
#     subprocess.run(ffmpeg_cmd, stdout=subprocess.PIPE, stderr=subprocess.PIPE)

#     return {
#         "Title": info.get("title"),
#         "Author": info.get("uploader"),
#         "Views": info.get("view_count"),
#         "Clip_Path": final_file
#     }

# %%
from moviepy.editor import VideoFileClip

def video_to_images(video_path,output_folder):
  clip = VideoFileClip(video_path)
  clip.write_images_sequence(
      os.path.join(output_folder, "frame%04d.png"),fps=0.2
  )

# %%
def video_to_audio(video_path,output_audio_path):
  clip = VideoFileClip(video_path)
  audio = clip.audio
  audio.write_audiofile(output_audio_path)

# %%
sr.Recognizer?

# %%
def audio_to_text(audio_path):
  recognizer=sr.Recognizer()
  audio=sr.AudioFile(audio_path)

  with audio as source:
    audio_data=recognizer.record(source)

    try:

      #recognize the speech
      text = recognizer.recognize_whisper(audio_data)

    except sr.UnknownValueError:
      print("Speech recognition could not understand the audio.")
  return text

# %%
video_to_images(file_path,output_folder)
# Out:
# Moviepy - Writing frames /content/mixed_data/frame%04d.png.
# Moviepy - Done writing frames /content/mixed_data/frame%04d.png.

# %%
video_to_audio(file_path, output_audio_path)
# Out:
# MoviePy - Writing audio in /content/mixed_data/output_audio.wav
# MoviePy - Done.

# %%
text_data = audio_to_text(output_audio_path)

# %%
text_data
# Out:
# " You've probably heard the story of how Reddit is selling their data to Google for AI scraping, how automatic is selling all the WordPress and Tumblr data, and now how financial times is selling their data to open AI. And this doesn't sound right, because we've been told that these AI companies are taking all this data and basically invalidating the data sources they're coming from by sharing the data so you don't get to the source. So what exactly is happening here? This is more complicated than it sounds. You see, there are two different things these AI companies can do with the data. One is use it for training, you know, building new models based on the data and they're definitely doing that in some respect. But the other one is to use the data as a grounded source. And that's really interesting. So let me explain. Here's a very simplified drawing of what happens when you use AI system like Chatchy PT. You put in a prompt, the prompt goes to the AI system and the AI system create
# ...

# %%
with open(output_folder + "output_text.txt", "w") as file:
  file.write(text_data)
file.close()

# %%
os.remove(output_audio_path)

# %%
from llama_index.core.indices import MultiModalVectorStoreIndex
from llama_index.core import SimpleDirectoryReader
from llama_index.core import StorageContext

# %%
from llama_index.vector_stores.lancedb import LanceDBVectorStore

# %%
text_store = LanceDBVectorStore(uri = "lancedb", table_name = "text_collection")
image_store = LanceDBVectorStore(uri = "lancedb", table_name = "image_collection")
# Out:
# WARNING:llama_index.vector_stores.lancedb.base:Table text_collection doesn't exist yet. Please add some data to create it.
# WARNING:llama_index.vector_stores.lancedb.base:Table image_collection doesn't exist yet. Please add some data to create it.

# %%
storage_context = StorageContext.from_defaults(vector_store = text_store, image_store = image_store)

# %%
output_folder
# Out:
# '/content/mixed_data/'

# %%
documents = SimpleDirectoryReader(output_folder).load_data()

# %%
len(documents)
# Out:
# 37

# %%
index = MultiModalVectorStoreIndex.from_documents(documents,storage_context=storage_context)
# Out:
# 100%|████████████████████████████████████████| 338M/338M [00:02<00:00, 170MiB/s]

# %%
retriever_engine = index.as_retriever(similarity_top_k = 1, image_similarity_top_k = 5)

# %%
from llama_index.core.response.notebook_utils import display_source_node
from llama_index.core.schema import ImageNode

# %%
def retrieve(retriever_engine, query_str):
  retrieveal_results = retriever_engine.retrieve(query_str)

  retrieved_image = []
  retrieved_text = []

  for res_node in retrieveal_results:
    if isinstance(res_node.node, ImageNode):
      retrieved_image.append(res_node.node.metadata["file_path"])
    else:
      display_source_node(res_node, source_length=200)
      retrieved_text.append(res_node.text)
  return retrieved_image,retrieved_text

# %%
query = "Tell me about RAG"

img, text = retrieve(retriever_engine, query)
# Out:
# **Node ID:** 79de09aa-885b-4e48-b5fc-4e5887d95820<br>**Similarity:** 0.5730592012405396<br>**Text:** You've probably heard the story of how Reddit is selling their data to Google for AI scraping, how automatic is selling all the WordPress and Tumblr data, and now how financial times is selling the...<br>

# %%
img
# Out:
# ['/content/mixed_data/frame0000.png',
#  '/content/mixed_data/frame0001.png',
#  '/content/mixed_data/frame0007.png',
#  '/content/mixed_data/frame0009.png',
#  '/content/mixed_data/frame0032.png']

# %%
import matplotlib.pyplot as plt
def plot_images(images_path):
  images_shown = 0
  plt.figure(figsize=(16, 9))
  for img_path in images_path:
        if os.path.isfile(img_path):
            image = Image.open(img_path)

            plt.subplot(2, 3, images_shown + 1)
            plt.imshow(image)
            plt.xticks([])
            plt.yticks([])

            images_shown += 1
            if images_shown >= 5:
                break

# %%
plot_images(img)

# %%
qa_tmpl_str=(
    "Based on the provided information, including relevant images and retrieved context from the video, \
    accurately and precisely answer the query without any additional prior knowledge.\n"

    "---------------------\n"
    "Context: {context_str}\n"
    "Metadata for video: {metadata_str} \n"

    "---------------------\n"
    "Query: {query_str}\n"
    "Answer: "
)

# %%
metadata_vid
# Out:
# {'Title': 'AI Explained: What is RAG - Retrieval Augmented Generation?',
#  'Author': 'Morten Rand-Hendriksen',
#  'Views': 31629}

# %%
import json
metadata_str = json.dumps(metadata_vid)

# %%
metadata_str
# Out:
# '{"Title": "AI Explained: What is RAG - Retrieval Augmented Generation?", "Author": "Morten Rand-Hendriksen", "Views": 31629}'

# %%
img
# Out:
# ['/content/mixed_data/frame0000.png',
#  '/content/mixed_data/frame0001.png',
#  '/content/mixed_data/frame0007.png',
#  '/content/mixed_data/frame0009.png',
#  '/content/mixed_data/frame0032.png']

# %%
image_documents =  SimpleDirectoryReader(input_files=img).load_data()

# %%
image_documents
# Out:
# [ImageDocument(id_='7747a3ae-7f6e-4238-bd1b-951bae28bd53', embedding=None, metadata={'file_path': '/content/mixed_data/frame0000.png', 'file_name': 'frame0000.png', 'file_type': 'image/png', 'file_size': 1006011, 'creation_date': '2026-06-21', 'last_modified_date': '2026-06-21'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=None, image_resource=MediaResource(embeddings=None, data=None, text=None, path=PosixPath('/content/mixed_data/frame0000.png'), url=None, mimetype='image/png'), audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
# ...

# %%
from llama_index.multi_modal_llms.openai import OpenAIMultiModal
from llama_index.core.llms import ImageBlock

img_base64_bytes = [ImageBlock(image = image_document.resolve_image(as_base64 = True).read()) for image_document in image_documents]

# %%
img_base64_bytes
# Out:
# [ImageBlock(block_type='image', image=b'...', path=None, url=None, image_mimetype='image/png', detail=None),
#  ImageBlock(block_type='image', image=b'...', path=None, url=None, image_mimetype='image/png', detail=None),
#  ImageBlock(block_type='image', image=b'...', path=None, url=None, image_mimetype='image/png', detail=None),
#  ImageBlock(block_type='image', image=b'...', path=None, url=None, image_mimetype='image/png', detail=None),
#  ImageBlock(block_type='image', image=b'...', path=None, url=None, image_mimetype='image/png', detail=None)]

# %%
openai_mm_llm = OpenAIMultiModal(
    model = "gpt-5.4", api_key = userdata.get('OPENAI_API_KEY')
)
# Out:
# WARNING:py.warnings:/tmp/ipykernel_2556/2467575157.py:1: DeprecationWarning: Call to deprecated class OpenAIMultiModal. (The package has been deprecated and will no longer be maintained. Please use llama-index-llms-openai (preferably the Responses API) instead. See Multi Modal LLMs documentation for a complete guide on migration: https://docs.llamaindex.ai/en/stable/understanding/using_llms/using_llms/#multi-modal-llms) -- Deprecated since version 0.5.2.
#   openai_mm_llm = OpenAIMultiModal(

# %%
context_str = "\n".join(text)

# %%
response = openai_mm_llm.complete(
    prompt = qa_tmpl_str.format(
        context_str = context_str, query_str = query, metadata_str = metadata_str
    ),
    image_documents = img_base64_bytes,
)

pprint(response)
# Out:
# CompletionResponse(text='RAG stands for **Retrieval Augmented Generation**.\n\nBased on the video, RAG is a way of making AI responses more reliable by having the AI **retrieve information from a grounded source first**, and then use that information to generate its answer.\n\n### How it works\nInstead of only doing this:\n\n**Prompt → AI system → Completion**\n\nRAG does this:\n\n**Prompt → AI system → grounded source/database → relevant information returned → AI system → grounded response**\n\n### Why RAG is used\nThe video explains that if an AI answers only from its training, it may produce something that **looks correct** but is really just assembling tokens into plausible language. That means there is **no guarantee the answer is correct**.\n\nRAG helps solve that by grounding the answer in **real data** from an external source, such as a database or licensed media content.\n\n### Why this matters\nThe context mentions deals where media companies provide data to AI companies. A
# ...

# %%
query = "Capital of India"
response_1 = openai_mm_llm.complete(
    prompt = qa_tmpl_str.format(
        context_str = context_str, query_str = query, metadata_str = metadata_str
    ),
    image_documents = img_base64_bytes,
)

# %%
pprint(response_1)
# Out:
# CompletionResponse(text='The provided context does not state the capital of India, so it cannot be answered accurately from the given information alone.', additional_kwargs={'prompt_tokens': 13115, 'completion_tokens': 26, 'total_tokens': 13141}, raw=ChatCompletion(id='chatcmpl-Dt8ayDAD4iqA4Ql6SPmf6qpGjNfg3', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='The provided context does not state the capital of India, so it cannot be answered accurately from the given information alone.', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None))], created=1782033452, model='gpt-5.4-2026-03-05', object='chat.completion', moderation=None, service_tier='default', system_fingerprint=None, usage=CompletionUsage(completion_tokens=26, prompt_tokens=13115, total_tokens=13141, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_predic
# ...
